# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
df1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M", header=0)

# %%
df2=df1[0]

# %%
df2.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df2.head()
# Out:
#    M1A      Not assigned    Not assigned.1
# 0  M2A      Not assigned      Not assigned
# 1  M3A        North York         Parkwoods
# 2  M4A        North York  Victoria Village
# 3  M5A  Downtown Toronto      Harbourfront
# 4  M5A  Downtown Toronto       Regent Park

# %%
filtered= df2[~df2.Borough.str.contains('Not assigned' , case=False)]

# %%
filtered.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %%
f1=pd.DataFrame(filtered.groupby('Borough', axis='columns'))

# %%
f1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
filtered.groupby('Postcode').Neighbourhood.agg([('Borough', 'unique'),('Neighbourhood', ', '.join)])
# Out:
#                                                     Borough  \
# Postcode
# M1B                                        [Rouge, Malvern]
# M1C                [Highland Creek, Rouge Hill, Port Union]
# M1E                     [Guildwood, Morningside, West Hill]
# M1G                                                [Woburn]
# M1H                                             [Cedarbrae]
# M1J                                   [Scarborough Village]
# M1K           [East Birchmount Park, Ionview, Kennedy Park]
# M1L                       [Clairlea, Golden Mile, Oakridge]
# M1M       [Cliffcrest, Cliffside, Scarborough Village West]
# M1N                           [Birch Cliff, Cliffside West]
# M1P       [Dorset Park, Scarborough Town Centre, Wexford...
# M1R                                     [Maryvale, Wexford]
# M1S                                             [Agincourt]
# M1T               [Clarks Corners, Sullivan, Tam O'Shanter]
# ...
